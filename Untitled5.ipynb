# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
import csv
from matplotlib import colors
from matplotlib.ticker import PercentFormatter

# %%
df = pd.read_csv(r"C:\Users\ptlon\Desktop\New folder (5)\rate_analysis_2020_test_20200310 (1) (4) (5).csv")
df.head()
# Out:
#         SA_ID  Date_Of_Analysis  Analysis_Start_Date  Analysis_End_Date  \
# 0   561878133             43880                43490              43856
# 1  1600523616             43880                43502              43866
# 2  3713216762             43880                43511              43875
# 3   721681344             43880                43505              43871
# 4  1170186217             43880                43494              43858
#
#   Current_Rate Current_Rate_Orig  Current_Rate_Eff_Date  DA  CCA  TBS  ...  \
# 0           E1               HE1                  43831 NaN    Y  NaN  ...
# 1           E1                E1                  43831 NaN    Y  NaN  ...
# 2           E1                E1                  43831 NaN    Y  NaN  ...
# 3           E1                E1                  43831 NaN    Y  NaN  ...
# 4           E1              HE1N                  43831 NaN  NaN  NaN  ...
#
#   RA_MC_3 RA_MC_4 RA_MC_5 RA_MC_6 RA_MC_7 RA_MC_8 RA_MC_9 RA_MC_10  \
# ...

# %%
df.shape
# Out:
# (999, 57)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=999, step=1)

# %%
df.columns
# Out:
# Index(['SA_ID', 'Date_Of_Analysis', 'Analysis_Start_Date', 'Analysis_End_Date',
#        'Current_Rate', 'Current_Rate_Orig', 'Current_Rate_Eff_Date', 'DA',
#        'CCA', 'TBS', 'CARE', 'FERA', 'SR', 'SC', 'MB', 'EE', 'NEMS',
#        'Bill_Cycle', 'RateCompared1', 'RateCompared1_Amt',
#        'RateCompared1_NR_Amt', 'RateCompared1_CPP_Amt',
#        'RateCompared1_CPP_NR_Amt', 'RateCompared2', 'RateCompared2_Amt',
#        'RateCompared2_NR_Amt', 'RateCompared2_CPP_Amt',
#        'RateCompared2_CPP_NR_Amt', 'RateCompared3', 'RateCompared3_Amt',
#        'RateCompared3_NR_Amt', 'RateCompared3_CPP_Amt',
#        'RateCompared3_CPP_NR_Amt', 'RateCompared4', 'RateCompared4_Amt',
#        'RateCompared4_NR_Amt', 'RateCompared4_CPP_Amt',
#        'RateCompared4_CPP_NR_Amt', 'RateCompared5', 'RateCompared5_Amt',
#        'RateCompared5_NR_Amt', 'RateCompared5_CPP_Amt',
#        'RateCompared5_CPP_NR_Amt', 'Version', 'Amount_Saved', 'RA_MC_1',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 57 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   SA_ID                     999 non-null    int64
#  1   Date_Of_Analysis          999 non-null    int64
#  2   Analysis_Start_Date       999 non-null    int64
#  3   Analysis_End_Date         999 non-null    int64
#  4   Current_Rate              999 non-null    object
#  5   Current_Rate_Orig         999 non-null    object
#  6   Current_Rate_Eff_Date     999 non-null    int64
#  7   DA                        0 non-null      float64
#  8   CCA                       530 non-null    object
#  9   TBS                       6 non-null      object
#  10  CARE                      265 non-null    object
#  11  FERA                      5 non-null      object
#  12  SR                        11 non-null     object
# ...

# %%
df.count()
# Out:
# SA_ID                       999
# Date_Of_Analysis            999
# Analysis_Start_Date         999
# Analysis_End_Date           999
# Current_Rate                999
# Current_Rate_Orig           999
# Current_Rate_Eff_Date       999
# DA                            0
# CCA                         530
# TBS                           6
# CARE                        265
# FERA                          5
# SR                           11
# SC                            1
# MB                           47
# EE                            7
# NEMS                        118
# Bill_Cycle                  999
# RateCompared1               991
# RateCompared1_Amt           991
# RateCompared1_NR_Amt        991
# RateCompared1_CPP_Amt       385
# RateCompared1_CPP_NR_Amt    385
# RateCompared2               991
# RateCompared2_Amt           991
# RateCompared2_NR_Amt        991
# RateCompared2_CPP_Amt       386
# RateCompared2_CPP_NR_Amt    386
# RateCompared3               991
# ...

# %%
df.fillna('', inplace=True)
df.dropna()
# Out:
#           SA_ID  Date_Of_Analysis  Analysis_Start_Date  Analysis_End_Date  \
# 0     561878133             43880                43490              43856
# 1    1600523616             43880                43502              43866
# 2    3713216762             43880                43511              43875
# 3     721681344             43880                43505              43871
# 4    1170186217             43880                43494              43858
# ..          ...               ...                  ...                ...
# 994  9327358454             43880                43502              43866
# 995   291475021             43880                43497              43861
# 996  2999428678             43880                43484              43851
# 997  4950525577             43880                43494              43858
# 998   809276375             43880                43487              43851
#
#     Current_Rate Current_Rate_Orig  Current_Rate_Eff_Date DA CCA TBS  ...  \
# ...

# %%
df.head()
# Out:
#         SA_ID  Date_Of_Analysis  Analysis_Start_Date  Analysis_End_Date  \
# 0   561878133             43880                43490              43856
# 1  1600523616             43880                43502              43866
# 2  3713216762             43880                43511              43875
# 3   721681344             43880                43505              43871
# 4  1170186217             43880                43494              43858
#
#   Current_Rate Current_Rate_Orig  Current_Rate_Eff_Date DA CCA TBS  ...  \
# 0           E1               HE1                  43831      Y      ...
# 1           E1                E1                  43831      Y      ...
# 2           E1                E1                  43831      Y      ...
# 3           E1                E1                  43831      Y      ...
# 4           E1              HE1N                  43831             ...
#
#   RA_MC_3 RA_MC_4 RA_MC_5 RA_MC_6 RA_MC_7 RA_MC_8 RA_MC_9 RA_MC_10  \
# 0
# 1
# 2
# 3
# 4
#
# ...

# %%
df.to_excel
# Out:
# <bound method NDFrame.to_excel of           SA_ID  Date_Of_Analysis  Analysis_Start_Date  Analysis_End_Date  \
# 0     561878133             43880                43490              43856
# 1    1600523616             43880                43502              43866
# 2    3713216762             43880                43511              43875
# 3     721681344             43880                43505              43871
# 4    1170186217             43880                43494              43858
# ..          ...               ...                  ...                ...
# 994  9327358454             43880                43502              43866
# 995   291475021             43880                43497              43861
# 996  2999428678             43880                43484              43851
# 997  4950525577             43880                43494              43858
# 998   809276375             43880                43487              43851
#
# ...

# %%
df.to_csv('out.csv')

# %%
df.info('Current_Rate')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 57 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   SA_ID                     999 non-null    int64
#  1   Date_Of_Analysis          999 non-null    int64
#  2   Analysis_Start_Date       999 non-null    int64
#  3   Analysis_End_Date         999 non-null    int64
#  4   Current_Rate              999 non-null    object
#  5   Current_Rate_Orig         999 non-null    object
#  6   Current_Rate_Eff_Date     999 non-null    int64
#  7   DA                        999 non-null    object
#  8   CCA                       999 non-null    object
#  9   TBS                       999 non-null    object
#  10  CARE                      999 non-null    object
#  11  FERA                      999 non-null    object
#  12  SR                        999 non-null    object
#  13  SC                        999 non-null    object
# ...

# %%
sns.displot(df, x="Current_Rate", hue="Version")

# %% [markdown]
# #We can see the customers Current rate with each "version" of utilities they have.
